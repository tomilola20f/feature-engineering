# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("learningset.csv")
# Out:
# C:\Users\tomil\AppData\Local\Temp\ipykernel_18524\4231878936.py:1: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("learningset.csv")

# %%
df
# Out:
#        ODATEDW OSOURCE  TCODE STATE    ZIP MAILCODE PVASTATE   DOB NOEXCH  \
# 0         8901     GRI      0    IL  61081                    3712      0
# 1         9401     BOA      1    CA  91326                    5202      0
# 2         9001     AMH      1    NC  27017                       0      0
# 3         8701     BRY      0    CA  95953                    2801      0
# 4         8601              0    FL  33176                    2001      0
# ...        ...     ...    ...   ...    ...      ...      ...   ...    ...
# 95407     9601     ASE      1    AK  99504                       0      0
# 95408     9601     DCD      1    TX  77379                    5001      0
# 95409     9501     MBC      1    MI  48910                    3801      0
# 95410     8601     PRV      0    CA  91320                    4005      0
# 95411     8801     MCC      2    NC  28409                    1801      0
#
#       RECINHSE  ... TARGET_D HPHONE_D RFA_2R RFA_2F RFA_2A MDMAUD_R  MDMAUD_F  \
# 0               ...      0.0        0      L      4      E        X         X
# 1               ...      0.0        0      L      2      G        X         X
# 2               ...      0.0        1      L      4      E        X         X
# 3               ...      0.0        1      L      4      E        X         X
# 4            X  ...      0.0        1      L      2      F        X         X
# ...        ...  ...      ...      ...    ...    ...    ...      ...       ...
# 95407           ...      0.0        0      L      1      G        X         X
# 95408           ...      0.0        1      L      1      F        X         X
# 95409           ...      0.0        1      L      3      E        X         X
# 95410        X  ...     18.0        1      L      4      F        X         X
# 95411        X  ...      0.0        1      L      1      G        C         1
#
#       MDMAUD_A CLUSTER2 GEOCODE2
# 0            X     39.0        C
# 1            X      1.0        A
# 2            X     60.0        C
# 3            X     41.0        C
# 4            X     26.0        A
# ...        ...      ...      ...
# 95407        X     12.0        C
# 95408        X      2.0        A
# 95409        X     34.0        B
# 95410        X     11.0        A
# 95411        C     12.0        C
#
# [95412 rows x 481 columns]

# %%
numerical = df.select_dtypes(include=np.number)

# %%
numerical
# Out:
#        ODATEDW  TCODE   DOB   AGE  NUMCHLD  INCOME  WEALTH1  HIT  MBCRAFT  \
# 0         8901      0  3712  60.0      NaN     NaN      NaN    0      NaN
# 1         9401      1  5202  46.0      1.0     6.0      9.0   16      0.0
# 2         9001      1     0   NaN      NaN     3.0      1.0    2      0.0
# 3         8701      0  2801  70.0      NaN     1.0      4.0    2      0.0
# 4         8601      0  2001  78.0      1.0     3.0      2.0   60      1.0
# ...        ...    ...   ...   ...      ...     ...      ...  ...      ...
# 95407     9601      1     0   NaN      NaN     NaN      NaN    0      NaN
# 95408     9601      1  5001  48.0      1.0     7.0      9.0    1      0.0
# 95409     9501      1  3801  60.0      NaN     NaN      NaN    0      NaN
# 95410     8601      0  4005  58.0      NaN     7.0      NaN    0      NaN
# 95411     8801      2  1801  80.0      NaN     5.0      8.0    3      0.0
#
#        MBGARDEN  ...  FISTDATE  NEXTDATE  TIMELAG    AVGGIFT  CONTROLN  \
# 0           NaN  ...      8911    9003.0      4.0   7.741935     95515
# 1           0.0  ...      9310    9504.0     18.0  15.666667    148535
# 2           0.0  ...      9001    9101.0     12.0   7.481481     15078
# 3           0.0  ...      8702    8711.0      9.0   6.812500    172556
# 4           0.0  ...      7903    8005.0     14.0   6.864865      7112
# ...         ...  ...       ...       ...      ...        ...       ...
# 95407       NaN  ...      9602       NaN      NaN  25.000000    184568
# 95408       0.0  ...      9603       NaN      NaN  20.000000    122706
# 95409       NaN  ...      9410    9501.0      3.0   8.285714    189641
# 95410       NaN  ...      8612    8704.0      4.0  12.146341      4693
# 95411       0.0  ...      8803    8809.0      6.0  96.794872    185114
#
#        TARGET_B  TARGET_D  HPHONE_D  RFA_2F  CLUSTER2
# 0             0       0.0         0       4      39.0
# 1             0       0.0         0       2       1.0
# 2             0       0.0         1       4      60.0
# 3             0       0.0         1       4      41.0
# 4             0       0.0         1       2      26.0
# ...         ...       ...       ...     ...       ...
# 95407         0       0.0         0       1      12.0
# 95408         0       0.0         1       1       2.0
# 95409         0       0.0         1       3      34.0
# 95410         1      18.0         1       4      11.0
# 95411         0       0.0         1       1      12.0
#
# [95412 rows x 407 columns]

# %% [markdown]
# ## Check for null values in the numerical columns

# %%
numerical.isna().sum()
# Out:
# ODATEDW         0
# TCODE           0
# DOB             0
# AGE         23665
# NUMCHLD     83026
#             ...
# TARGET_B        0
# TARGET_D        0
# HPHONE_D        0
# RFA_2F          0
# CLUSTER2      132
# Length: 407, dtype: int64

# %% [markdown]
# ## Use appropriate methods to clean the columns GEOCODE2, WEALTH1, ADI, DMA,and MSA.

# %%
droplist = numerical.loc[:, ["WEALTH1","ADI","DMA","MSA"]]#GEOCODE2 is not in the data
droplist
# Out:
#        WEALTH1    ADI    DMA     MSA
# 0          NaN  177.0  682.0     0.0
# 1          9.0   13.0  803.0  4480.0
# 2          1.0  281.0  518.0     0.0
# 3          4.0   67.0  862.0  9340.0
# 4          2.0  127.0  528.0  5000.0
# ...        ...    ...    ...     ...
# 95407      NaN    0.0  743.0   380.0
# 95408      9.0  201.0  618.0  3360.0
# 95409      NaN   61.0  551.0  4040.0
# 95410      NaN   13.0  803.0  8735.0
# 95411      8.0  355.0  550.0  9200.0
#
# [95412 rows x 4 columns]

# %%
numerical.drop(droplist,axis=1,inplace=True)

# %%
numerical
# Out:
#        ODATEDW  TCODE   DOB   AGE  NUMCHLD  INCOME  HIT  MBCRAFT  MBGARDEN  \
# 0         8901      0  3712  60.0      NaN     NaN    0      NaN       NaN
# 1         9401      1  5202  46.0      1.0     6.0   16      0.0       0.0
# 2         9001      1     0   NaN      NaN     3.0    2      0.0       0.0
# 3         8701      0  2801  70.0      NaN     1.0    2      0.0       0.0
# 4         8601      0  2001  78.0      1.0     3.0   60      1.0       0.0
# ...        ...    ...   ...   ...      ...     ...  ...      ...       ...
# 95407     9601      1     0   NaN      NaN     NaN    0      NaN       NaN
# 95408     9601      1  5001  48.0      1.0     7.0    1      0.0       0.0
# 95409     9501      1  3801  60.0      NaN     NaN    0      NaN       NaN
# 95410     8601      0  4005  58.0      NaN     7.0    0      NaN       NaN
# 95411     8801      2  1801  80.0      NaN     5.0    3      0.0       0.0
#
#        MBBOOKS  ...  FISTDATE  NEXTDATE  TIMELAG    AVGGIFT  CONTROLN  \
# 0          NaN  ...      8911    9003.0      4.0   7.741935     95515
# 1          3.0  ...      9310    9504.0     18.0  15.666667    148535
# 2          1.0  ...      9001    9101.0     12.0   7.481481     15078
# 3          0.0  ...      8702    8711.0      9.0   6.812500    172556
# 4          9.0  ...      7903    8005.0     14.0   6.864865      7112
# ...        ...  ...       ...       ...      ...        ...       ...
# 95407      NaN  ...      9602       NaN      NaN  25.000000    184568
# 95408      1.0  ...      9603       NaN      NaN  20.000000    122706
# 95409      NaN  ...      9410    9501.0      3.0   8.285714    189641
# 95410      NaN  ...      8612    8704.0      4.0  12.146341      4693
# 95411      0.0  ...      8803    8809.0      6.0  96.794872    185114
#
#        TARGET_B  TARGET_D  HPHONE_D  RFA_2F  CLUSTER2
# 0             0       0.0         0       4      39.0
# 1             0       0.0         0       2       1.0
# 2             0       0.0         1       4      60.0
# 3             0       0.0         1       4      41.0
# 4             0       0.0         1       2      26.0
# ...         ...       ...       ...     ...       ...
# 95407         0       0.0         0       1      12.0
# 95408         0       0.0         1       1       2.0
# 95409         0       0.0         1       3      34.0
# 95410         1      18.0         1       4      11.0
# 95411         0       0.0         1       1      12.0
#
# [95412 rows x 403 columns]

# %%
 import seaborn as sns

# %%
sns.distplot(numerical)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
couldnt proceed EDA
